# %%
import pandas as pd
from re import search

# %%
df=pd.read_excel(r'/Users/smani/Downloads/Sample_2(Anju).xlsx')

# %%
jobtitle = set(df["jobtitle"].tolist())

# %%
resumetitle =df["resume_job_title"].tolist()

# %%
workss = df["Forwork"].tolist()

# %%
df["employments"][1]
# Out:
# '[{"Employer":"Bakers Waterstreet Bar and Grill","Position":"Head server","DateFrom":{"UtcYear":2019,"UtcMonth":5,"UtcDay":1},"DateCompanyStart":{"UtcYear":2019,"UtcMonth":5,"UtcDay":1},"Classifications":{"Classifications":{"onet17":[{"Code":"35-3031.00","Name":"Waiters and Waitresses","Score":79,"Taxonomy":"onet17","Source":"EdgeEmploymentClassification","Sources":["EdgeEmploymentClassification"]}],"carotenev3":[{"Code":"35.12","Name":"Server","Score":48,"Taxonomy":"carotenev3","Source":"EdgeEmploymentClassification","Sources":["EdgeEmploymentClassification"]}]}},"Source":"AnonymousResume","Sources":["AnonymousResume","EdgeEmploymentClassification"]}]'

# %%
for i in jobtitle :
    for j in workss :
        if operator.contains(j.lower(),i.lower()):
            print ("Jobtitle: "+i+" "+"Resumetitle: "+j)
        else:
            pass
# Out:
# Jobtitle: Accounts Payable Specialist Resumetitle: Accounts Payable Specialist RD74PM67B165SJD3CJ8
# Jobtitle: Accounts Payable Specialist Resumetitle: Accounts Payable Specialist RCM72R73VDNZ019C9N5
# Jobtitle: Accounts Payable Specialist Resumetitle: Accounts Payable Specialist R2H36M5X2ZZ22N40NHF
# Jobtitle: Accounts Payable Specialist Resumetitle: Accounts Payable Specialist R2Z3ML76MXQPF21Q2JY
# Jobtitle: Accounts Payable Specialist Resumetitle: Accounts Payable Specialist R2H36M5X2ZZ22N40NHF
# Jobtitle: Accounts Payable Specialist Resumetitle: Accounts Payable Specialist R2S2MX77N8ZPXSBQ2T8
# Jobtitle: Accounts Payable Specialist Resumetitle: Accounts Payable Specialist R2S50R6X39C5BYR7LGB
# Jobtitle: Medical Receptionist Resumetitle: Medical Receptionist RD70NV6882DHRJ885J9
# Jobtitle: Medical Receptionist Resumetitle: Medical Receptionist RDH6NQ62D92P4T4765K
# Jobtitle: Medical Receptionist Resumetitle: Medical Receptionist RCM5NM6FZ47CWCP0WXP
# ...

# %%
import operator

fullstring =["Desktop Support Technician",
"Desktop Support",
"Desktop Technician",
"Desktop Support Technician",
"Terry Woods ResumetestII2118.doc",
"Help Desk Technician",
"Desktop Support Specialist",
"Senior Desktop Technician",
"Tax Accountant/CPA",
"Audit/Tax Accountant",
"Staff/Tax  Accountant",
"Tax Accountant",
"Tax Accountant"]

substring = ["Desktop Support","Tax Accountant"]

# %%
for i in substring :
    for j in fullstring:
        if operator.contains(j.lower(),i.lower()):
            print ("Found!"+i+" "+j)
        else:
            pass
# Out:
# Found!Desktop Support Desktop Support Technician
# Found!Desktop Support Desktop Support
# Found!Desktop Support Desktop Support Technician
# Found!Desktop Support Desktop Support Specialist
# Found!Tax Accountant Tax Accountant/CPA
# Found!Tax Accountant Audit/Tax Accountant
# Found!Tax Accountant Tax Accountant
# Found!Tax Accountant Tax Accountant

# %%
number_list = []
n = int(input("Enter the list size "))

print("\n")
for i in range(0, n):
    print("Enter number at index", i, )
    item = int(input())
    number_list.append(item)
print("User list is ", number_list)
sumlist = 0
sumlist1 = 0
# Out:
# Enter the list size 5
#
#
# Enter number at index 0
# 1
# Enter number at index 1
# 2
# Enter number at index 2
# 3
# Enter number at index 3
# 4
# Enter number at index 4
# 5
# User list is  [1, 2, 3, 4, 5]

# %%
newlist=[]
for k in number_list:
    s = k*n
    newlist.append(s)

# %%
newlist
# Out:
# [5, 10, 15, 20, 25]

# %%
for j in number_list:
    sumlist = j+sumlist
