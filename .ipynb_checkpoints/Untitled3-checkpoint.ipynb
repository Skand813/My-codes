# %%
import wikipedia
s=wikipedia.page("Python").title
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
s

# %%
import pandas as pd
df = pd.read_excel(r'/Users/smani/Downloads/skills_taxonomy.xlsx')

# %%
skills = df["skill"].tolist()

# %%
skills_l = []
for x in skills:
    if isinstance(x,str):
        for y in x :
            if y.isalpha():
                skills_l.append(x.lower())
                break
                
            
            
    
    else :
        pass
    
print(skills_l)
# Out:
# ['zenz', 'xextx', 'xintx', 'rrnarr', 'udayu', 'entry level', 'ufau', 'vfoodv', 'truck driver', 'driver', 'rreurr', 'automotive', 'transport', 'vguestv', 'semi driver', 'team', 'driver', 'wfoodw', 'commercial drivers license', 'dot', 'owner operator', 'transportation', 'truck driver', 'company truck driver', 'rrapacrr', 'transportation jobs', 'tractor trailer', 'vculv', 'wculw', 'delivery', 'full time', 'logistics', 'local', 'over the road', 'manager', 'transportation', 'class a truck driver', 'whskpw', 'truck driver school', 'part time', 'long haul', 'over the road', 'vhskpv', 'wguestw', 'semi', 'drivers', 'job placement', 'regional driver', 'business', 'new business', 'company driver', 'team driver', 'entry level', 'sports', 'class a', 'truck', 'zesz', 'long haul driver', 'xotherx', 'new markets', 'vsalesv', 'driver jobs', 'communication', 'student truck drivers', 'truck driver schools', 'military', 'account executive', 'account manager', 'shipping', 'over the road driver', 'license
# ...

# %%
final_skill = list(dict.fromkeys(skills_l))

# %%
len(final_skill)
# Out:
# 28557

# %%
len (skills_l)
# Out:
# 37871
