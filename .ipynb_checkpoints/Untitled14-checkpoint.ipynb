# %%
import pandas as pd

df4 = pd.read_excel(r'/Users/smani/Downloads/Book1_sn.xlsx')
xls = pd.ExcelFile(r'/Users/smani/Downloads/Skills_desc_total_local.xlsx')
df1 = pd.read_excel(xls, 'Manual_Batch')
df2 = pd.read_excel(xls, 'skills_tk_batch')
df3 = pd.read_excel(xls, 'skillsv5_en_full_novecs')

# %%
df4
# Out:
#                          id            category  \
# 0      KS00JX7N0NNYOGJKAL9I            Language
# 1      KS01CEMFI8VW30MHZWZ6            IT Skill
# 2      KS01DEB4LPFRK5GHUFHR  Professional Skill
# 3      KS01PLPFCNVAW2HEQKEI  Professional Skill
# 4      KS02DLFSYG5QZER3BM82  Professional Skill
# ...                     ...                 ...
# 10938  KSZXS4KAZ0P1M8KP5SZE            IT Skill
# 10939  KSZY4FFHBCGCUAMPK8VU            IT Skill
# 10940  KSZY4TXOC5UXT9N49PF3            Language
# 10941  KSZYCV24ZQ940ZDUGU4B            IT Skill
# 10942  KSZZTNGKTELLOCXIUHZX            IT Skill
#
#                           display_name
# 0                             Kashmiri
# 1                               Db2400
# 2                Industry Developments
# 3      Lift Servicing and Installation
# 4                         Incoterm Use
# ...                                ...
# 10938                     Apache Storm
# 10939                  Data Generation
# ...

# %%
desc_dict1 = dict(zip(df1.Skill_Id, df2.Description))
desc_dict2 = dict(zip(df2.Did, df3.Description))
desc_dict3 = dict(zip(df3.skill_Id, df3.Description))

# %%
desc_list = df4["id"].tolist()
desc_list=list( dict.fromkeys(desc_list) )
