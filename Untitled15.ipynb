# %%
pip install jsondiff
# Out:
# ...
#   Created wheel for jsondiff: filename=jsondiff-1.2.0-py3-none-any.whl size=6539 sha256=992bf5005b13a3ec476654512639396d3cf8307b8cec518f95eaffe97f1de0c6
#   Stored in directory: /Users/smani/Library/Caches/pip/wheels/13/19/b3/9065e430a7cd8215f03a27af9d3352b8b4833a22204856c1bd
# Successfully built jsondiff
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from jsondiff import diff
import pandas as pd

df1 = pd.read_json(r'/Users/smani/Documents/fcsvjson.json')
df2 = pd.read_json(r'/Users/smani/Documents/scsvjson.json')

# %%
diff(df2,df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-d92ea0d173b2> in <module>
# ----> 1 diff(df2,df1)
#
# /opt/anaconda3/lib/python3.7/site-packages/jsondiff/__init__.py in diff(a, b, fp, cls, **kwargs)
#     595
#     596 def diff(a, b, fp=None, cls=JsonDiffer, **kwargs):
# --> 597     return cls(**kwargs).diff(a, b, fp)
#     598
#     599
#
# /opt/anaconda3/lib/python3.7/site-packages/jsondiff/__init__.py in diff(self, a, b, fp)
#     499             b = self.options.loader(b)
#     500
# --> 501         d, s = self._obj_diff(a, b)
#     502
#     503         if self.options.marshal or self.options.dump:
#
# /opt/anaconda3/lib/python3.7/site-packages/jsondiff/__init__.py in _obj_diff(self, a, b)
#     489         elif isinstance(a, set) and isinstance(b, set):
#     490             return self._set_diff(a, b)
# --> 491         elif a != b:
# ...

# %%
desc_list1 = df1["fname"].tolist()
desc_list2 = df2["sname"].tolist()

# %%
diff_r = desc_list2-desc_list1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-de5fc012df62> in <module>
# ----> 1 diff_r = desc_list2-desc_list1
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
def list_diff(list1, list2):
    out = []
    for ele in list1:
        if not ele in list2:
            out.append(ele)
    return out

# %%
result =list_diff(desc_list2,desc_list1)

# %%
len(result)
# Out:
# 10

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import json
import time

#nowtime = time.time()

#f1=open("Extra" + str(nowtime) + ".json", "w+")
browser = webdriver.Firefox(executable_path = "/Users/smani/.wdm/drivers/geckodriver/macos/v0.28.0/geckodriver")
browser.get('https://www.sgi.sk.ca/drivereducator')

while True :
    try:
        click_item = browser.find_element_by_xpath('(//button[@class="load-more btn-2 ng-scope"])')
        click_item.click()
    except (NoSuchElementException,RuntimeError, TypeError, NameError):
        break
searchElem2 = browser.find_elements_by_xpath('(//article[@class="row details-wrapper ng-scope"])')
school =[]
for j in searchElem2 :
        results2 = j.text
        school.append(results2)
        #print(school) 
#f1.write(str(school) + ",")

# %%
searchElem2 = browser.find_elements_by_xpath('(//article[@class="row details-wrapper ng-scope"])/h4')

# %%
website = browser.find_elements_by_xpath('(//article[@class="row details-wrapper ng-scope"]/@href)')
# Out:
# 'Warren Zubko'

# %%
result_dict = dict() 
searchelem3 =browser.find_elements_by_xpath('(//*[@id="content"]/div[3]/article/div[2]/article[20]/ul/li/a)')

    
#title = browser.find_elements_by_xpath('(//article[@class="row details-wrapper ng-scope"]/h4)')

# %%
search4 = browser.find_elements_by_xpath('(//\\[@class="u-pull-left btn-1 btn-sm btn"])')

# %%
search4[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-f8a98aa2a085> in <module>
# ----> 1 search4[0].text
#
# IndexError: list index out of range

# %%
browser.close()

# %%
while click_item.click():
    searchElem2 = browser.find_elements_by_xpath('(//article[@class="row details-wrapper ng-scope"])')

# %%
school =[]
for j in searchElem2 :
        results2 = j.text
        school.append(results2)
        print(re.sub(r"[\n\t]*", "", school))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-326b82bc0dfa> in <module>
#       1 school =[]
# ----> 2 for j in searchElem2 :
#       3         results2 = j.text
#       4         school.append(results2)
#       5         print(re.sub(r"[\n\t]*", "", school))
#
# NameError: name 'searchElem2' is not defined

# %%
import docx

def getText(filename) :
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return ('\n').join(fullText)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-df2a861b40a9> in <module>
# ----> 1 import docx
#       2
#       3 def getText(filename) :
#       4     doc = docx.Document(filename)
#       5     fullText = []
#
# ModuleNotFoundError: No module named 'docx'

# %%
pip install docx
# Out:
# ...
#      |████████████████████████████████| 54 kB 841 kB/s eta 0:00:01
# ...
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53923 sha256=8af9e5ff1d3ff3154e952db1856c947f7a9d3cd77f0021357aabf98b31aa7061
#   Stored in directory: /Users/smani/Library/Caches/pip/wheels/dc/ac/45/846e21706415c92fc6e0964e343be1eb31cfc63e149dee5fbe
# Successfully built docx
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx
def getText(filename) :
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return ('\n').join(fullText)

# %%
pip install python-docx
# Out:
# ...
#      |████████████████████████████████| 5.5 MB 1.2 MB/s eta 0:00:01
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.10-py3-none-any.whl size=184490 sha256=69e613b8b30cd540645c965d5747c500a122c95ff0a28c15e00a99b840f290bd
#   Stored in directory: /Users/smani/Library/Caches/pip/wheels/75/c6/69/05491f32dc052cd70476b65f5bf7082a9b274045f6b001b821
# Successfully built python-docx
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import smtplib
conn =smtplib.SMTP("smtp.gmail.com",587)
conn.ehlo()
conn.starttls()
conn.login('EMAIL address','EMAIL password')
conn.sendmail('Sender Email','Reciever Email','Subject : Text......\n\n Hi Skand,\n This is test mail from python script')
conn.quit()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [103.211.16.172]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
conn.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
conn.login('maniskand813@gmail.com','dinesh@813')
# Out:
# (235, b'2.7.0 Accepted')

# %%
conn.sendmail('maniskand813@gmail.com','maniskand813@gmail.com','Subject : Test mail from Jupyter.\n\n Hi Skand,\n This is test mail from python script')
# Out:
# {}

# %%
conn.quit()
# Out:
# (221, b'2.0.0 closing connection g30sm12015359pfr.152 - gsmtp')

# %%
import pdftotext

# Load your PDF
with open(r'/Users/smani/Documents/ans-driver-road-safety-programs-active-licences.pdf', 'rb') as f:
    pdf = pdftotext.PDF(f)

# If it's password-protected
#with open("secure.pdf", "rb") as f:
   # pdf = pdftotext.PDF(f, "secret")

# How many pages?
print(len(pdf))

# Iterate over all the pages
for page in pdf:
    print(page)

# Read some individual pages
#print(pdf[0])
#print(pdf[1])

# Read all the text into one string
print("\n\n".join(pdf))
# Out:
# 12
#                                                                 Road Safety Programs
#                                                                      Active Licences
#      Name                                        Civic Address                       GDL Approved Phone Number   Issue Date Expiry Date
# Licence Type: Driving School
#      1ST CLASS DRIVING SCHOOL
#      Contact Name: ERIC MACRAE 902-565-0582
#      Licence Number: 863547998 NS0001            39 SHERWOOD DRIVE                                (902) 565-0582 Dec/31/19  Dec/31/20
#                                                  SYDNEY RIVER, NS B1S1J9
#      ACCESS DRIVING ACADEMY
#      Contact Name: FERESHTEH ASHORI
#      Licence Number: 796610871 NS0001            305 TRANSOM DRIVE                   Yes          (902) 877-2146 Dec/31/20  Dec/31/21
#                                                  HALIFAX, NS B3M0L7
#      ALTIMATE DRIVER TRAINING
#      Franchise Name: YOUNG DRIVER'S OF CANADA
# ...

# %%
pip install tabulate
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabula import read_pdf
from tabulate import tabulate

file= r'/Users/smani/Documents/ans-driver-road-safety-programs-active-licences.pdf'

# %%
table =read_pdf(file,pages=1)
# Out:
# Error from tabula-java:
# No Java runtime present, requesting install.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-3-dbac7beca1c3> in <module>
# ----> 1 table =read_pdf(file,pages=1)
#
# /opt/anaconda3/lib/python3.7/site-packages/tabula/io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     320
#     321     try:
# --> 322         output = _run(java_options, kwargs, path, encoding)
#     323     finally:
#     324         if temporary:
#
# /opt/anaconda3/lib/python3.7/site-packages/tabula/io.py in _run(java_options, options, path, encoding)
#      83             stderr=subprocess.PIPE,
#      84             stdin=subprocess.DEVNULL,
# ---> 85             check=True,
#      86         )
#      87         if result.stderr:
#
# ...

# %%
pip install camelot-py
# Out:
# ...
#      |████████████████████████████████| 42 kB 711 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.6 MB 1.4 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import camelot

tables = camelot.read_pdf(r'/Users/smani/Documents/ans-driver-road-safety-programs-active-licences.pdf')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-a4ee4c3249d7> in <module>
# ----> 1 import camelot
#       2
#       3 tables = camelot.read_pdf(r'/Users/smani/Documents/ans-driver-road-safety-programs-active-licences.pdf')
#
# /opt/anaconda3/lib/python3.7/site-packages/camelot/__init__.py in <module>
#       4
#       5 from .__version__ import __version__
# ----> 6 from .io import read_pdf
#       7 from .plotting import PlotMethods
#       8
#
# /opt/anaconda3/lib/python3.7/site-packages/camelot/io.py in <module>
#       3 import warnings
#       4
# ----> 5 from .handlers import PDFHandler
#       6 from .utils import validate_input, remove_extra
#       7
#
# /opt/anaconda3/lib/python3.7/site-packages/camelot/handlers.py in <module>
#       6 from PyPDF2 import PdfFileReader, PdfFileWriter
#       7
# ----> 8 from .core import TableList
# ...

# %%
import docx
 
def getText(filename) :
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    #    #newname = re.sub(r"[\\n]*", "", str(fullText))
    return fullText
#for i in fullText()

# %%
getText(r'/Users/smani/Documents/Newfound_1.docx')
# Out:
# ['Newfoundland and Labrador Graduated Driver Licensing Program Approved Driving Schools',
#  '',
#  '',
#  'NFLD SAFETY COUNCIL',
#  '',
#  '84-86 Elizabeth Ave.',
#  "St. John's, NL\tA1A 1W7",
#  'Phone: (709) 754-0210',
#  '',
#  'PENINSULA DRIVER TRAINING SCHOOL',
#  '',
#  'P.O. Box 1071',
#  'Marystown, NL\tA0E 2M0',
#  'Phone: (709) 279-4111',
#  '',
#  'CENTRAL TRAINING ACADEMY Box 400, 15 Main St. Badger, NL A0H 1A0 Phone(709) 539-5150',
#  '',
#  "GRADUATE DRIVER TRAINING 48 Paddy Dobbin Dr. St. John's, NL A1A 4V6 Phone: (709) 754-3999",
#  '',
#  'D.R.I.V.E.',
#  '',
#  'P.O. Box 69 Elliston',
#  'Trinity Bay, NL A0C 1N0',
#  'Phone: (709) 468-2020',
#  '',
#  'ACE DRIVING SCHOOL',
#  '',
#  '16 Viking Place',
#  'Clarenville, NL A5A 2A6',
#  'Phone: (709) 466-5158',
#  '',
#  "DAVE'S DEFENSIVE DRIVING SCHOOL",
#  '',
#  '30 B Lower Avenue',
#  "Bishop's Falls, NL\tA0H 1C0",
#  'Phone: (709) 486-4883',
#  '',
#  'E - Z DRIVING SCHOOL',
#  '',
#  '34 Third Avenue',
# ...

# %%
import docx
import re


doc = docx.Document(r'/Users/smani/Documents/Newfound_1.docx')
fullText = []
for para in doc.paragraphs:
        fullText.append(para.text)

# %%
for i in range(1,len(fullText)):
    result = re.sub("\n","",fullText[i])
    print(result)
# Out:
# NFLD SAFETY COUNCIL
#
# 84-86 Elizabeth Ave.
# St. John's, NL	A1A 1W7
# Phone: (709) 754-0210
#
# PENINSULA DRIVER TRAINING SCHOOL
#
# P.O. Box 1071
# Marystown, NL	A0E 2M0
# Phone: (709) 279-4111
#
# CENTRAL TRAINING ACADEMY Box 400, 15 Main St. Badger, NL A0H 1A0 Phone(709) 539-5150
#
# GRADUATE DRIVER TRAINING 48 Paddy Dobbin Dr. St. John's, NL A1A 4V6 Phone: (709) 754-3999
#
# D.R.I.V.E.
#
# P.O. Box 69 Elliston
# Trinity Bay, NL A0C 1N0
# Phone: (709) 468-2020
#
# ACE DRIVING SCHOOL
#
# 16 Viking Place
# Clarenville, NL A5A 2A6
# Phone: (709) 466-5158
#
# DAVE'S DEFENSIVE DRIVING SCHOOL
#
# 30 B Lower Avenue
# Bishop's Falls, NL	A0H 1C0
# Phone: (709) 486-4883
#
# E - Z DRIVING SCHOOL
#
# 34 Third Avenue
# Pasadena, NL A0L 1K0
# Phone: (709) 686-5571
#
# YOUNG DRIVERS OF CANADA
#
# 55 Elizabeth Ave
# St. John's, NL	A1A 1W9
# Phone: (709) 737-1695
#
# SAFEWAY DRIVING SCHOOL 33 Florida Loop Stephenville, NL A2N 2W9 Phone: (709) 643-9003
#
# WESTERN DRIVING SCHOOL
#
# Box 1002
# ...

# %%
list1 = data["Data_scrap"].tolist()

# %%
import re
#objre =re.compile(r'(/d/d/d).*(/d/d/d).*(/d/d/d/d)')
for i in list1 :
    x = re.findall(r'.*(/d/d/d).*(/d/d/d).*(/d/d/d/d)', i)
    #if re.search(i) is True :
    print(x)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
import re
matchdict = {}

for i in list1 :
    new_list = []
    result =re.search(r'(\d{10})',i.replace(" ", ""))
    if result == None :
        new_list.append(i)
    else :
        pass
    matchdict["Inst"] ="Centre_Details"
    matchdict["Value"]= new_list
    print(matchdict)
# Out:
# {}
# {}
# {}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-214fef935ec2> in <module>
#       9     else :
#      10         matchdict["Inst"] ="Centre_Details"
# ---> 11         matchdict["Value"]= new_list[:i]
#      12
#      13
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
import re
matchdict = {}
new_list = []
for i,j in enumerate(list1) :
    
    result =re.search(r'(\d{10})',j.replace(" ", ""))
    if result == None :
        continue
    else :
        new_list.append(int(i))
    
    print(new_list)
# Out:
# [3]
# [3, 8]
# [3, 8, 13]
# [3, 8, 13, 17]
# [3, 8, 13, 17, 22]
# [3, 8, 13, 17, 22, 27]
# [3, 8, 13, 17, 22, 27, 32]
# [3, 8, 13, 17, 22, 27, 32, 37]
# [3, 8, 13, 17, 22, 27, 32, 37, 42]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60, 64]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60, 64, 69]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60, 64, 69, 73]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60, 64, 69, 73, 78]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60, 64, 69, 73, 78, 82]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60, 64, 69, 73, 78, 82, 86]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60, 64, 69, 73, 78, 82, 86, 90]
# [3, 8, 13, 17, 22, 27, 32, 37, 42, 46, 51, 56, 60, 64, 69, 73, 78, 82, 86, 90, 94]
# ...

# %%
new_dict = dict()
new_list2 = []
for i in list1[:100] :
    
    result =re.search(r'(\d{10})',i.replace(" ", ""))
    if result == None :
        new_list2.append(i)
    else :
        new_list3 = []
        for j in new_list2:
            new_list3.append(j)
        new_dict["Entry"] = i
        new_dict["Value"] = new_list3
        new_list2 = []
        continue
    print(new_dict)
# Out:
# {}
# {}
# {}
# {'Entry': '      905 703 5197     ', 'Value': ['      Wheels Driver Training      ', '      21 Cedar Road  Acton  ', ' L7J 2V2      ']}
# {'Entry': '      905 703 5197     ', 'Value': ['      Wheels Driver Training      ', '      21 Cedar Road  Acton  ', ' L7J 2V2      ']}
# {'Entry': '      905 703 5197     ', 'Value': ['      Wheels Driver Training      ', '      21 Cedar Road  Acton  ', ' L7J 2V2      ']}
# {'Entry': '      905 703 5197     ', 'Value': ['      Wheels Driver Training      ', '      21 Cedar Road  Acton  ', ' L7J 2V2      ']}
# {'Entry': '      905 420 8641     ', 'Value': ['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ']}
# {'Entry': '      905 420 8641     ', 'Value': ['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ']}
# ...

# %%
import pandas as pd
import json
f=open("Ontario" + ".json", "w+")
filename=r'/Users/smani/scrapy_projects/extra_work/data_set.csv'
data=pd.read_csv(filename)
list1 = data["Data_scrap"].tolist()
new_dict = dict()
new_list2 = []
for i in list1:
    
    result =re.search(r'(\d{10})',i.replace(" ", ""))
    if result == None :
        new_list2.append(i)
    else :
        new_list3 = []
        for j in new_list2:
            new_list3.append(j)
        new_list3.append(i)
        #new_dict["Entry"] = "Ontario_Data"
        new_dict["Results"] = new_list3
        values1 = new_dict.values()
        values_list = list(values1)
        
        
        print(values_list)
        f.write(str(values_list)+",")
        #print(new_dict)
        new_list2 = []
        continue
# Out:
# [['      Wheels Driver Training      ', '      21 Cedar Road  Acton  ', ' L7J 2V2      ', '      905 703 5197     ']]
# [['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ', '      905 420 8641     ']]
# [['      Best Choice Driving School      ', '       Digital Curriculum Available       ', '          1 Rossland Road West  Suite 203  Ajax ', ' L1Z 1Z2      ', '      647 889 4985 905 686 2224     ']]
# [['      Durham s Elite Driving School Inc       ', '      30 Hunt Street  Suite 205  Ajax  ', ' L1S 7H2      ', '      905 626 1039     ']]
# [['      Eric s Driving Academy      ', ' Digital Curriculum Available       ', '      40 Old Kingston Road  Unit 224  Ajax ', ' L1T 2Z7      ', '      905 427 7109     ']]
# [['      Next Gen Driving School', '   Digital Curriculum Available ', '  3 Harwood Ave South  Unit 202  Ajax  ', ' L1S 2C1', '  416 788 7444']]
# ...

# %%
import pandas as pd
import json
filename=r'/Users/smani/Documents/query-hive-501711.csv'
data=pd.read_csv(filename)

# %%
data
# Out:
#                  source_linkedin_social123_au_ca.json  \
# 0   {"_Key":"US225fe638fb42f96b","Full_Name":"Mich...
# 1   {"_Key":"USe926eb5437bb949d","Full_Name":"Shar...
# 2   {"_Key":"US44052cb285202180","Full_Name":"Mich...
# 3   {"_Key":"USc1800a931d83e9ed","Full_Name":"Mike...
# 4   {"_Key":"US265cf8a400d2fd6c","Full_Name":"Trac...
# 5   {"_Key":"USf48e643a7e965ea6","Full_Name":"Scot...
# 6   {"_Key":"US2d3489de70658c7c","Full_Name":"Jame...
# 7   {"_Key":"USc2b80c4afbf8fc90","Full_Name":"Jean...
# 8   {"_Key":"USe28c07be05fcca96","Full_Name":"Greg...
# 9   {"_Key":"CA7c9feb6fa43572c1","Full_Name":"Xiao...
# 10  {"_Key":"UK235931ba4e7b743a","Full_Name":"Geor...
# 11  {"_Key":"US4f01c9639b1e6495","Full_Name":"Jona...
# 12  {"_Key":"USa69f065459708fd4","Full_Name":"Kier...
# 13  {"_Key":"USabdb1abba55c1bfb","Full_Name":"Prit...
# 14  {"_Key":"3d00604a-3db1-491c-a5de-4295b130abe6"...
# 15  {"_Key":"US9014d58327172e51","Full_Name":"Judi...
# ...

# %%
list2 = data["source_linkedin_social123_au_ca.primary_key"].tolist()

# %%
list2
# Out:
# ['michael-feliciano-69181628',
#  'sharoq-alam-a5b9631a',
#  'michael-le-0512967',
#  'mike-nelson-6b554b5',
#  'trace-martyn-3aa6b225',
#  'scclifford',
#  'jamesarowland',
#  'jean-genest-7973b42a',
#  'gregory-saxton-65618246',
#  'xiaoshi-cici-wang-42b96558',
#  'georgia-darlow-7ba58b2b',
#  'jbondc',
#  'kieron-evans-95994631',
#  'pritpal-dhillon-02ba9969',
#  'roxann-kobelt-9643ab9b',
#  'judith-martin-91292133',
#  'imadmouaddine',
#  'terry-li-6942266b',
#  'doug-bailey-2b6b77bb',
#  'brennan-ccs-93851775',
#  'sam-cook-58a615b1',
#  'sandra-maju-11809955',
#  'mattjohnston4',
#  'monika-work-etzler-1b00511b',
#  'a-a-b3b99245',
#  'caitriona-carragher-54115a6a',
#  'romankomarov',
#  'brittany-de-cortes-balague-39362346',
#  'stephen-brown-2894bb7',
#  'christen-gelinas-03737056',
#  'gayla-bural-82880a8a',
#  'jerry-haasch-89b6511a',
#  'heidi-brakhage-babb807b',
#  'walter-moses-b7a89941',
#  'nathan-porte-91a11824',
#  'ebienvenu',
#  'ronald-donkersloot-6b83575b',
# ...

# %%
list1 = data["source_linkedin_social123_au_ca.json"].tolist()

# %%
new_list = []
for i in list1[:10]:
    mylist = i.replace(' ','').split(',')
    new_list.append(mylist)

# %%
new_list[0]
# Out:
# ['{"_Key":"US225fe638fb42f96b"',
#  '"Full_Name":"MichaelFeliciano"',
#  '"Given_Name":"Michael"',
#  '"Family_Name":"Feliciano"',
#  '"LinkedIn_Id":"97574221"',
#  '"Canonical_URL":"http://www.linkedin.com/in/michael-feliciano-69181628"',
#  '"Headline":"NYBoxingExamineratExaminer.com"',
#  '"Locality":"GreaterNewYorkCityArea"',
#  '"Industry":"OnlineMedia"',
#  '"Num_Connections":"4"',
#  '"Interests":""',
#  '"Country":"US"',
#  '"IsCASL":false',
#  '"Updated":"2015-09-30T18:00:09"',
#  '"Current_Company_URL":"www.insideview.com/directory/examiner-com"',
#  '"Current_Company_Name":"Examiner.com"',
#  '"Current_Company_Position":"NYBoxingExaminer"',
#  '"Email_Address":""',
#  '"CompanyId":"70635AB30D7D22C60DF5C8434057EA1C"',
#  '"URL":"http://www.linkedin.com/in/michael-feliciano-69181628"',
#  '"Certifications":[]',
#  '"Courses":[]',
#  '"Experience":[{"CompanyId":"70635AB30D7D22C60DF5C8434057EA1C"',
#  '"Company":"Examiner.com"',
# ...

# %%
for j in new_list:
    print(j[1])
# Out:
# "Full_Name":"MichaelFeliciano"
# "Full_Name":"SharoqAlam"
# "Full_Name":"MichaelLe"
# "Full_Name":"MikeNelson"
# "Full_Name":"TraceMartyn"
# "Full_Name":"ScottClifford"
# "Full_Name":"JamesRowland"
# "Full_Name":"JeanGenest"
# "Full_Name":"GregorySaxton"
# "Full_Name":"Xiaoshi(CiCi)Wang"

# %%
import pandas as pd
import json

filename=r'/Users/smani/Documents/query-hive-501711.csv'
data=pd.read_csv(filename)

list1 = data["source_linkedin_social123_au_ca.json"].tolist()
final_list=[]
new_list = []
for i in list1:
    mylist = i.replace(' ','').split(',')
    new_list.append(mylist)
    for j in new_list:
        final_list.append(j[1])

# %%
final_list
# Out:
# ['"Full_Name":"MichaelFeliciano"',
#  '"Full_Name":"MichaelFeliciano"',
#  '"Full_Name":"SharoqAlam"',
#  '"Full_Name":"MichaelFeliciano"',
#  '"Full_Name":"SharoqAlam"',
#  '"Full_Name":"MichaelLe"',
#  '"Full_Name":"MichaelFeliciano"',
#  '"Full_Name":"SharoqAlam"',
#  '"Full_Name":"MichaelLe"',
#  '"Full_Name":"MikeNelson"',
#  '"Full_Name":"MichaelFeliciano"',
#  '"Full_Name":"SharoqAlam"',
#  '"Full_Name":"MichaelLe"',
#  '"Full_Name":"MikeNelson"',
#  '"Full_Name":"TraceMartyn"',
#  '"Full_Name":"MichaelFeliciano"',
#  '"Full_Name":"SharoqAlam"',
#  '"Full_Name":"MichaelLe"',
#  '"Full_Name":"MikeNelson"',
#  '"Full_Name":"TraceMartyn"',
#  '"Full_Name":"ScottClifford"',
#  '"Full_Name":"MichaelFeliciano"',
#  '"Full_Name":"SharoqAlam"',
#  '"Full_Name":"MichaelLe"',
#  '"Full_Name":"MikeNelson"',
#  '"Full_Name":"TraceMartyn"',
#  '"Full_Name":"ScottClifford"',
#  '"Full_Name":"JamesRowland"',
#  '"Full_Name":"MichaelFeliciano"',
#  '"Full_Name":"SharoqAlam"',
# ...

# %%
import re
new_dic4 = {}
new_list4 =[]
for k in list2[:5]:
    obj_re = re.compile(k)
    for m in list1:
        if obj_re.search(m):
            mylist4 = m.replace(' ','').split(',')
            new_list4.append(mylist4)
            for j in new_list:
                new_dic4[k]=j[1]
                print(new_dic4)
# Out:
# {'michael-feliciano-69181628': '"Full_Name":"MichaelFeliciano"'}
# {'michael-feliciano-69181628': '"Full_Name":"SharoqAlam"'}
# {'michael-feliciano-69181628': '"Full_Name":"MichaelLe"'}
# {'michael-feliciano-69181628': '"Full_Name":"MikeNelson"'}
# {'michael-feliciano-69181628': '"Full_Name":"TraceMartyn"'}
# {'michael-feliciano-69181628': '"Full_Name":"ScottClifford"'}
# {'michael-feliciano-69181628': '"Full_Name":"JamesRowland"'}
# {'michael-feliciano-69181628': '"Full_Name":"JeanGenest"'}
# {'michael-feliciano-69181628': '"Full_Name":"GregorySaxton"'}
# {'michael-feliciano-69181628': '"Full_Name":"Xiaoshi(CiCi)Wang"'}
# {'michael-feliciano-69181628': '"Full_Name":"GeorgiaDarlow"'}
# {'michael-feliciano-69181628': '"Full_Name":"JonathanBond-Caron"'}
# {'michael-feliciano-69181628': '"Full_Name":"KieronEvans"'}
# {'michael-feliciano-69181628': '"Full_Name":"PritpalDhillon"'}
# {'michael-feliciano-69181628': '"Full_Name":"RoxannKobelt"'}
# ...
