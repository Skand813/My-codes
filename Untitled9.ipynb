# %%
import wikipedia
import json
import pandas as pd
from multiprocessing import Pool
import warnings
import time
#warnings.filterwarnings('ignore', category=GuessedAtParserWarning)
warnings.catch_warnings()

warnings.simplefilter("ignore")
nowtime = time.time()
#f1=open("Desc_Work_" + str(nowtime) + ".json", "w+")
#f2=open("NoDesc_Work_" + str(nowtime) + ".json", "w+")
desDict = dict()
skill_error_list1 = []
df = pd.read_json(r"/Users/smani/Downloads/data-4.json")
skill_list1 = df["Unique_CF"].tolist()
skill_list1 = skill_list1[:20]
desDict = dict()

def wiki_mapping(i) :
    
    try :
        desDict["Skill_name"]= i
        desDict["Description"] = wikipedia.summary(i,sentences=2)

    except wikipedia.exceptions.DisambiguationError as e :
        skill_error_list1.append(i)
        #json.dump(skill_error_list1,f2)
        print(e.options)
    except wikipedia.exceptions.PageError as e :
        skill_error_list1.append(i)
        #json.dump(skill_error_list1, f2)
        print(e)
    except ConnectionError as e:
        print(e)

    return (desDict,skill_error_list1)

#working_list = new_skills(skill_list)

p = Pool(10)
records = p.map(wiki_mapping,skill_list1)
#f1.write(str(records) + ",")

#f1.close()
#f2.close()
#print(records)
p.terminate()
p.join()

# %%
import wikipedia
import json
import pandas as pd
from multiprocessing import Pool
import warnings
import time
#warnings.filterwarnings('ignore', category=GuessedAtParserWarning)
warnings.catch_warnings()

warnings.simplefilter("ignore")
nowtime = time.time()
#f1=open("Wiki_Desc_Work_" + str(nowtime) + ".json", "w+")
f2=open("Wiki_NoDesc_Work_" + str(nowtime) + ".json", "w+")
desDict = dict()
skill_error_list1 = []
df = pd.read_json(r"/Users/smani/Downloads/data-4.json")
No_match_list = df[0].tolist()
skill_dict = dict()
skill_no_match_list=[]

for items in No_match_list[:100]:
    
    try :
        wikipedia.summary(items,sentences=2)
    
        #skill_dict["Skill_name"]= items
        #skill_dict["Description"] = wikipedia.summary(items,sentences=2)
        #f1.write((str(skill_dict) + ","))
        #print (skill_dict)

    except wikipedia.exceptions.DisambiguationError as e :
        skill_no_match_list.append(items)
        f2.write((str(skill_no_match_list) + ",")) 
        #json.dump(skill_error_list1,f2)
        #print(e.options)
    except wikipedia.exceptions.PageError as e :
        skill_no_match_list.append(items)
        f2.write((str(skill_no_match_list) + ",")) 
        #json.dump(skill_error_list1, f2)
        #print(e)
    except ConnectionError as e:
        pass
        #print(e)

# %%
import json
import pandas as pd
with open(r"/Users/smani/Downloads/data-6.json") as f:
  df = pd.DataFrame([json.loads(l) for l in f.readlines()])
print(df)  # Shows data frame as expected
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-22-b42803abc106> in <module>
#       2 import pandas as pd
#       3 with open(r"/Users/smani/Downloads/data-6.json") as f:
# ----> 4   df = pd.DataFrame([json.loads(l) for l in f.readlines()])
#       5 print(df)  # Shows data frame as expected
#
# <ipython-input-22-b42803abc106> in <listcomp>(.0)
#       2 import pandas as pd
#       3 with open(r"/Users/smani/Downloads/data-6.json") as f:
# ----> 4   df = pd.DataFrame([json.loads(l) for l in f.readlines()])
#       5 print(df)  # Shows data frame as expected
#
# /opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 2 column 1 (char 2)

# %%
df_n = pd.read_json(r"/Users/smani/Downloads/Merged_all.json")

# %%
df_n
# Out:
#                  Skill_name                                  Description_2sent
# 0         Business Software  Business software or a business application is...
# 1                Scheduling  A schedule or a timetable, as a basic time-man...
# 2        Content Management  Content management (CM) is a set of processes ...
# 3        Technology Roadmap  A technology roadmap is a flexible planning te...
# 4               Warehousing  A warehouse is a commercial building for stora...
# ...                     ...                                                ...
# 1020              Mix Paint  Thoroughly mix different types of paint manual...
# 1021   Budgetary Principles  Principles of estimating and planning of forec...
# 1022         Manage Payroll  Manage and be responsible for employees receiv...
# 1023       Electromechanics  The engineering processes that combine electri...
# 1024  Operate Machine Tools  Program and operate numerically controlled mac...
#
# [1025 rows x 2 columns]

# %%
df1 = pd.read_excel(r'/Users/smani/Downloads/skills_tk_batch_20201026.xls')
