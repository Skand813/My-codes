# %%
import pandas as pd
import re
import json
f=open("Ontario_3" + ".json", "w+")
filename=r'/Users/smani/scrapy_projects/extra_work/data_set.csv'
data=pd.read_csv(filename)
list1 = data["Data_scrap"].tolist()
new_dict = dict()
new_list2 = []
for i in list1:
    
    result =re.search(r'(\d{10})',i.replace(" ", ""))
    if result == None :
        new_list2.append(i)
    else :
        new_list3 = []
        for j in new_list2:
            new_list3.append(j)
        new_list3.append(i)
        #new_dict["Entry"] = "Ontario_Data"
        new_dict["Results"] = new_list3
        values1 = new_dict.values()
        #values_list = list(values1)
        
        
        print(values_list)
        f.write(str(values_list)+",")
        #print(new_dict)
        new_list2 = []
        continue
# Out:
# [['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ', '      905 420 8641     ']]
# [['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ', '      905 420 8641     ']]
# [['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ', '      905 420 8641     ']]
# [['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ', '      905 420 8641     ']]
# [['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ', '      905 420 8641     ']]
# ...

# %%
import pandas as pd
import json
f=open("Ontario123" + ".json", "w+")
filename=r'/Users/smani/scrapy_projects/extra_work/data_set.csv'
data=pd.read_csv(filename)
list1 = data["Data_scrap"].tolist()
new_dict = dict()
new_list2 = []
for i in list1:
    
    result =re.search(r'(\d{10})',i.replace(" ", ""))
    if result == None :
        new_list2.append(i)
    else :
        new_list3 = []
        for j in new_list2:
            new_list3.append(j)
        new_list3.append(i)
        #new_dict["Entry"] = "Ontario_Data"
        new_dict["Results"] = new_list3
        values1 = new_dict.values()
        #values_list = list(values1)
        f.write(str(values1)+",")
        
        print(values1)
        
        #print(new_dict)
        new_list2 = []
        continue
# Out:
# dict_values([['      Wheels Driver Training      ', '      21 Cedar Road  Acton  ', ' L7J 2V2      ', '      905 703 5197     ']])
# dict_values([['      All Seasons Driving School      ', ' Digital Curriculum Available       ', '            5 Harwood Avenue  Unit 205  Ajax ', ' L1S 2C1      ', '      905 420 8641     ']])
# dict_values([['      Best Choice Driving School      ', '       Digital Curriculum Available       ', '          1 Rossland Road West  Suite 203  Ajax ', ' L1Z 1Z2      ', '      647 889 4985 905 686 2224     ']])
# dict_values([['      Durham s Elite Driving School Inc       ', '      30 Hunt Street  Suite 205  Ajax  ', ' L1S 7H2      ', '      905 626 1039     ']])
# dict_values([['      Eric s Driving Academy      ', ' Digital Curriculum Available       ', '      40 Old Kingston Road  Unit 224  Ajax ', ' L1T 2Z7      ', '      905 427 7109     ']])
# ...

# %%
new_dict
# Out:
# {'Results': ['      Xpert Drivers       ',
#   '      2095 Weston Road  Unit 214  York  ',
#   ' M9N 1X7       ',
#   '      416 821 5913     ']}

# %%
import pandas as pd
import json
f=open("Ontario_phones" + ".json", "w+")
filename=r'/Users/smani/scrapy_projects/extra_work/data_set.csv'
data=pd.read_csv(filename)
list1 = data["Data_scrap"].tolist()
new_dict = dict()
new_list17 = []
for i in list1:
    result =re.search(r'(\d{10})',i.replace(" ", ""))
    if result == None :
        pass
    else :
        new_list17.append(i)
f.write(str(new_list17)+",")    
print(new_list17)
# Out:
# ['      905 703 5197     ', '      905 420 8641     ', '      647 889 4985 905 686 2224     ', '      905 626 1039     ', '      905 427 7109     ', '  416 788 7444', '      905 239 3535     ', '      905 426 9362     ', '      416 300 7073     ', '      613 632 2315 1 877 632 2315     ', '      613 623 2111 1 877 533 9507     ', '      647 400 0809     ', '      705 790 1833     ', '      705 728 1882     ', '      613 623 2111 1 877 533 9507     ', '      519 967 8383     ', '      905 578 7776 905 648 4888     ', '      905 547 7769     ', '      905 977 9633     ', '      705 424 4048     ', '      613 858 7242     ', '      613 623 2111  Cell   613 297 5302     ', '      519 938 7341     ', '      519 508 6150     ', '      613 623 2111 1 877 533 9507     ', '      807 623 6109     ', '      905 883 8500     ', '      416 820 1447', '      905 726 4132     ', '      905 895 8244     ', '      613 623 2111 1 877 533 9507     ', '      519 778 3730     ', '      519 273 1221     '
# ...

# %%
pip list
# Out:
# Package             Version
# ------------------- -------------------
# appnope             0.1.2
# argon2-cffi         20.1.0
# astroid             2.4.2
# async-generator     1.10
# attrs               20.3.0
# Automat             20.2.0
# autopep8            1.5.4
# backcall            0.2.0
# bcrypt              3.2.0
# beautifulsoup4      4.9.3
# bleach              3.2.1
# brotlipy            0.7.0
# bs4                 0.0.1
# certifi             2020.12.5
# cffi                1.14.4
# chardet             4.0.0
# constantly          15.1.0
# cryptography        3.3.1
# cssselect           1.1.0
# decorator           4.4.2
# defusedxml          0.6.0
# entrypoints         0.3
# hyperlink           21.0.0
# idna                2.10
# importlib-metadata  2.0.0
# incremental         17.5.0
# ipykernel           5.3.4
# ipython             7.19.0
# ipython-genutils    0.2.0
# isort               5.7.0
# jedi                0.18.0
# Jinja2              2.11.2
# ...

# %%
pip install pyspark
# Out:
# ...
#   Using cached pyspark-3.0.1-py2.py3-none-any.whl
# ...
#   Using cached py4j-0.10.9-py2.py3-none-any.whl (198 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyspark

# %%
from pyspark.sql.types import *
#import  pyspark
import  json
import  pandas as pd
import  ast

def parseFeatures(pref_features):
    pd_df= pref_features.toPandas()
    sallist=(pd_df[pd_df['prefkey'] == "desired_salary"]['prefvalue']).tolist()
    recent_incomelist=(pd_df[pd_df['prefkey'] == "recent_pay"]['prefvalue']).tolist()
    emp_type=(pd_df[pd_df['prefkey'] == "employment_type"]['prefvalue']).tolist()
    relocate_type=(pd_df[pd_df['prefkey'] == "relocate"]['prefvalue']).tolist()
    commute_type=(pd_df[pd_df['prefkey'] == "commute"]['prefvalue']).tolist()
    mgmt_exp_type = (pd_df[pd_df['prefkey'] == "mgmt_exp"]['prefvalue']).tolist()
    security_type = (pd_df[pd_df['prefkey'] == "security"]['prefvalue']).tolist()

    langs_typ = (pd_df[pd_df['prefkey'] == "languages"]['prefvalue']).tolist()
    #sec_cle_typ = (pd_df[pd_df['prefkey'] == "security"]['prefvalue']).tolist()
    #max_cmute_typ = (pd_df[pd_df['prefkey'] == "commute"]['prefvalue']).tolist()
    mgnd_hw_mny_typ = (pd_df[pd_df['prefkey'] == "mgmt_exp"]['prefvalue']).tolist()
    #job_typ_typ = (pd_df[pd_df['prefkey'] == "employment_type"]['prefvalue']).tolist()
    #mgnd_othrs_typ = (pd_df[pd_df['prefkey'] == "mgmt_exp"]['prefvalue']).tolist()
    acpt_trav_typ = (pd_df[pd_df['prefkey'] == "travel"]['prefvalue']).tolist()
    military_typ = (pd_df[pd_df['prefkey'] == "military"]['prefvalue']).tolist()
    nationality_typ = (pd_df[pd_df['prefkey'] == "nationality"]['prefvalue']).tolist()
    personal_summary_typ = (pd_df[pd_df['prefkey'] == "summary"]['prefvalue']).tolist()
    rcnt_title_typ = (pd_df[pd_df['prefkey'] == "current_job_title"]['prefvalue']).tolist()
    #rcnt_bonus_typ = (pd_df[pd_df['prefkey'] == "recent_pay"]['prefvalue']).tolist()

    highest_degree_typ = (pd_df[pd_df['prefkey'] == "highest_degree"]['prefvalue']).tolist()
    #rcnt_other_comp_typ = (pd_df[pd_df['prefkey'] == "recent_pay"]['prefvalue']).tolist()
    #webs3_typ = (pd_df[pd_df['prefkey'] == "other"]['prefvalue']).tolist()
    linked_in_profile_typ = (pd_df[pd_df['prefkey'] == "linkedin"]['prefvalue']).tolist()
    webs3_typ = (pd_df[pd_df['prefkey'] == "twitter"]['prefvalue']).tolist()
    facebook_profile_typ = (pd_df[pd_df['prefkey'] == "facebook"]['prefvalue']).tolist()

    availability_typ = (pd_df[pd_df['prefkey'] == "availability"]['prefvalue']).tolist()
    driverslicense_typ = (pd_df[pd_df['prefkey'] == "drivers_license"]['prefvalue']).tolist()
    creds_typ = (pd_df[pd_df['prefkey'] == "credentials"]['prefvalue']).tolist()
    #expected_salary_typ = (pd_df[pd_df['prefkey'] == "desired_salary"]['prefvalue']).tolist()
    intlskills_typ = (pd_df[pd_df['prefkey'] == "skills"]['prefvalue']).tolist()

    relo_abroad_typ = (pd_df[pd_df['prefkey'] == "relocate_abroad"]['prefvalue']).tolist()
    targ_loc_typ = (pd_df[pd_df['prefkey'] == "desired_locations"]['prefvalue']).tolist()
    #security_clr_lvl_typ = (pd_df[pd_df['prefkey'] == "security"]['prefvalue']).tolist()
    #workauth_typ = (pd_df[pd_df['prefkey'] == "work_auth"]['prefvalue']).tolist()
    #itskill_typ = (pd_df[pd_df['prefkey'] == "skills"]['prefvalue']).tolist()
    certifications_typ = (pd_df[pd_df['prefkey'] == "certifications"]['prefvalue']).tolist()




    allprofiles=list(set((pd_df['profileid'].tolist())))
    allfeatues=[]
    #{"income_pay": "", "income_type": "", "income_currency": ""}]
    for indx,eachprofile in enumerate(allprofiles):
        pro_featues = {}
        pro_featues['profileid']=eachprofile
        try:
            pro_featues['TARG_PAY']=ast.literal_eval(sallist[indx])[0]['income_pay']
            pro_featues['TARG_PAY_CRCY_TYP']=ast.literal_eval(sallist[indx])[0]['income_currency']
            pro_featues['TARG_PAY_TYP']=ast.literal_eval(sallist[indx])[0]['income_type']
        except :
            pro_featues['TARG_PAY']=""
            pro_featues['TARG_PAY_CRCY_TYP'] =""
            pro_featues['TARG_PAY_TYP']=""
        try:
            pro_featues['RCNT_PAY_CRCY_TYP'] = ast.literal_eval(recent_incomelist[indx])['income_currency']
            pro_featues['RCNT_INCM_TYP'] = ast.literal_eval(recent_incomelist[indx])['income_type']
            pro_featues['RCNT_INCM'] = ast.literal_eval(recent_incomelist[indx])['income_pay']
        except:
            pro_featues['RCNT_PAY_CRCY_TYP'] = ""
            pro_featues['RCNT_INCM_TYP'] = ""
            pro_featues['RCNT_INCM']=""
        try:
            pro_featues['DES_JOB_TYP']=ast.literal_eval(emp_type[indx])
        except:
            pro_featues['DES_JOB_TYP'] =[]
        try:
            pro_featues['relocate'] = relocate_type[indx]
        except:
            pro_featues['relocate'] = ""
        try:
            pro_featues['commute'] = ast.literal_eval(commute_type[indx])['maxcommute']
        except:
            pro_featues['commute'] = ""
        try:
            pro_featues['mgmt_exp'] = ast.literal_eval(mgmt_exp_type[indx])['mgmt']
        except:
            pro_featues['mgmt_exp'] = ""
        try:
            pro_featues['security'] = ast.literal_eval(security_type[indx])['security_clearance']
        except:
            pro_featues['security'] = ""
    #   to be added from below
        try:
            pro_featues['LANGS']=ast.literal_eval(langs_typ[indx])[0]['lang']
        except :
            pro_featues['LANGS']=""

        try:
            pro_featues['Security_Clearance']= ast.literal_eval(security_type[indx])['security_clearance']
        except:
            pro_featues['Security_Clearance'] = ""

        try:
            pro_featues['max_cmute'] = ast.literal_eval(commute_type[indx])['maxcommute']
        except :
            pro_featues['max_cmute'] =""

        try:
            pro_featues['mgnd_hw_mny'] = ast.literal_eval(mgmt_exp_type[indx])['how_many']
        except:
            pro_featues['mgnd_hw_mny'] =""

        try :
            pro_featues['mgnd_others'] = ast.literal_eval(mgmt_exp_type[indx])['mgmt']
        except:
            pro_featues['mgnd_others'] =""

        try:
            pro_featues['acpt_trav'] = acpt_trav_typ[indx]
        except:
            pro_featues['acpt_trav'] =""

        try :
            pro_featues['military'] = military_typ[indx]
        except:
            pro_featues['military'] = ""

        try:
            pro_featues['nationality'] = nationality_typ[indx]
        except:
            pro_featues['nationality'] =""

        try:
            pro_featues['personal_summary'] =personal_summary_typ[indx]
        except:
            pro_featues['personal_summary'] = ""

        try:
            pro_featues['rcnt_title'] = rcnt_title_typ[indx]
        except:
            pro_featues['rcnt_title'] = ""

        try:
            pro_featues['rcnt_bonus'] = ast.literal_eval(recent_incomelist[indx])['income_bonus']
        except:
            pro_featues['rcnt_bonus'] = ""

        try:
            pro_featues['highest_degree'] =highest_degree_typ[indx]
        except:
            pro_featues['highest_degree'] = ""

        try:
            pro_featues['rcnt_other_comp'] =ast.literal_eval(recent_incomelist[indx])['income_other']
        except :
            pro_featues['rcnt_other_comp'] = ""

        try:
            pro_featues['webs3'] =webs3_typ[indx]
        except :
            pro_featues['webs3'] = ""

        try:
            pro_featues['facebook_profile']= facebook_profile_typ[indx]
        except :
            pro_featues['facebook_profile'] =""

        try:
            pro_featues['rcnt_paid_time_off'] =ast.literal_eval(recent_incomelist[indx])['pto']
        except:
            pro_featues['rcnt_paid_time_off'] =""

        try:
            pro_featues['rcnt_commission_typ'] =ast.literal_eval(recent_incomelist[indx])['income_commission']
        except:
            pro_featues['rcnt_commission_typ'] =""

        try:
            pro_featues['rcnt_dentalinsurance'] = ast.literal_eval(recent_incomelist[indx])['dentalins']
        except:
            pro_featues['rcnt_dentalinsurance'] = ""

        try:
            pro_featues['rcnt_healthinsurance'] =ast.literal_eval(recent_incomelist[indx])['healthins']
        except:
            pro_featues['rcnt_healthinsurance'] = ""

        try:
            pro_featues['availability'] = availability_typ[indx]
        except:
            pro_featues['availability'] =""

        try:
            pro_featues['driverslicense_typ'] =driverslicense_typ[indx]
        except:
            pro_featues['driverslicense_typ'] =""

        try:
            pro_featues['creds_typ'] =creds_typ[indx]
        except:
            pro_featues['creds_typ'] =""

        try:
            pro_featues['expected_salary'] =ast.literal_eval(sallist[indx])[0]['income_pay']
        except:
            pro_featues['expected_salary'] =""

        try:
            pro_featues['intlskills'] = ast.literal_eval(intlskills_typ[indx])[0]['skill']
        except:
            pro_featues['intlskills'] = ""

        try:
            pro_featues['targ_commute'] = ast.literal_eval(commute_type[indx])['targetcommute']
        except:
            pro_featues['targ_commute'] =""

        try:
            pro_featues['relo_abroad'] =relo_abroad_typ[indx]
        except:
            pro_featues['relo_abroad'] =""

        try:
            pro_featues['targ_loc'] =ast.literal_eval(targ_loc_typ[indx])[0]['city']
        except:
            pro_featues['targ_loc'] =""

        try:
            pro_featues['certifications'] =ast.literal_eval(certifications_typ[indx])[0]['name']
        except:
            pro_featues['certifications'] =""

        try:
            pro_featues['linked_in_profile'] =linked_in_profile_typ[indx]
        except:
            pro_featues['linked_in_profile'] =""



        allfeatues.append(pro_featues)
    return allfeatues
if __name__ == '__main__':
    filename="/Users/smani/Desktop/query-hive-505970.csv"
    x=pd.read_csv(filename)
    p=parseFeatures(x)
    print(p)
    print(type(p))
    sdf = pd.DataFrame(p)
    print(type(sdf))
    # try:
    #     allprofilesData = execute_query(merge_query)
    #     allprofilesData.write.format("hive").mode("append").saveAsTable("edgetest.pp_rsachdeva_user")
    #     edu_spark_df = execute_query(edu_query)
    #     edu_spark_df.write.format("hive").mode("append").saveAsTable("edgetest.pp_rsachdeva_edu")
    #     exp_spark_df = execute_query(exp_query)
    #     exp_spark_df.write.format("hive").mode("append").saveAsTable("edgetest.pp_rsachdeva_exp")
    #     pref_features = execute_query(pref_other_features)
    #     data=parseFeatures(pref_features)
    #     pdf = pd.DataFrame(data)
    #     sdf = spark.createDataFrame(pdf)
    #     sdf.write.format("hive").mode("append").saveAsTable("edgetest.pp_rsachdeva_features")
    #
    #
    #
    # except Exception as r2:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-efdf5718f12c> in <module>
#     246     filename="/Users/smani/Desktop/query-hive-505970.csv"
#     247     x=pd.read_csv(filename)
# --> 248     p=parseFeatures(x)
#     249     print(p)
#     250     print(type(p))
#
# <ipython-input-6-efdf5718f12c> in parseFeatures(pref_features)
#       6
#       7 def parseFeatures(pref_features):
# ----> 8     pd_df= pd.read_csv(pref_features)
#       9     sallist=(pd_df[pd_df['prefkey'] == "desired_salary"]['prefvalue']).tolist()
#      10     recent_incomelist=(pd_df[pd_df['prefkey'] == "recent_pay"]['prefvalue']).tolist()
#
# ...

# %%
from pyspark.sql import *
import  json
import  pandas as pd
import  ast

def parseFeatures(pref_features):
    pd_df= pref_features.toPandas()
    sallist=(pd_df[pd_df['prefkey'] == "desired_salary"]['prefvalue']).tolist()
    recent_incomelist=(pd_df[pd_df['prefkey'] == "recent_pay"]['prefvalue']).tolist()
    emp_type=(pd_df[pd_df['prefkey'] == "employment_type"]['prefvalue']).tolist()
    relocate_type=(pd_df[pd_df['prefkey'] == "relocate"]['prefvalue']).tolist()
    commute_type=(pd_df[pd_df['prefkey'] == "commute"]['prefvalue']).tolist()
    mgmt_exp_type = (pd_df[pd_df['prefkey'] == "mgmt_exp"]['prefvalue']).tolist()
    security_type = (pd_df[pd_df['prefkey'] == "security"]['prefvalue']).tolist()
    
    allprofiles=list(set((pd_df['profileid'].tolist())))
    allfeatues=[]
    #{"income_pay": "", "income_type": "", "income_currency": ""}]
    for indx,eachprofile in enumerate(allprofiles):
        pro_featues = {}
        pro_featues['profileid']=eachprofile
        try:
            pro_featues['TARG_PAY']=ast.literal_eval(sallist[indx])[0]['income_pay']
            pro_featues['TARG_PAY_CRCY_TYP']=ast.literal_eval(sallist[indx])[0]['income_currency']
            pro_featues['TARG_PAY_TYP']=ast.literal_eval(sallist[indx])[0]['income_type']
        except :
            pro_featues['TARG_PAY']=""
            pro_featues['TARG_PAY_CRCY_TYP'] =""
            pro_featues['TARG_PAY_TYP']=""
        try:
            pro_featues['RCNT_PAY_CRCY_TYP'] = ast.literal_eval(recent_incomelist[indx])['income_currency']
            pro_featues['RCNT_INCM_TYP'] = ast.literal_eval(recent_incomelist[indx])['income_type']
            pro_featues['RCNT_INCM'] = ast.literal_eval(recent_incomelist[indx])['income_pay']
        except:
            pro_featues['RCNT_PAY_CRCY_TYP'] = ""
            pro_featues['RCNT_INCM_TYP'] = ""
            pro_featues['RCNT_INCM']=""
        try:
            pro_featues['DES_JOB_TYP']=ast.literal_eval(emp_type[indx])
        except:
            pro_featues['DES_JOB_TYP'] =[]
        try:
            pro_featues['relocate'] = relocate_type[indx]
        except:
            pro_featues['relocate'] = ""
        try:
            pro_featues['commute'] = ast.literal_eval(commute_type[indx])['maxcommute']
        except:
            pro_featues['commute'] = ""
        try:
            pro_featues['mgmt_exp'] = ast.literal_eval(mgmt_exp_type[indx])['mgmt']
        except:
            pro_featues['mgmt_exp'] = ""
        try:
            pro_featues['security'] = ast.literal_eval(security_type[indx])['security_clearance']
        except:
            pro_featues['security'] = ""
        allfeatues.append(pro_featues)
    return allfeatues
if __name__ == '__main__':
    filename="/Users/smani/Desktop/query-hive-505970.csv"
    x=pd.read_csv(filename)
    p=parseFeatures(x)
    print(p)
    print(type(p))
    sdf = pd.DataFrame(p)
    print(type(sdf))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-db383f91432d> in <module>
#      61     filename="/Users/smani/Desktop/query-hive-505970.csv"
#      62     x=pd.read_csv(filename)
# ---> 63     p=parseFeatures(x)
#      64     print(p)
#      65     print(type(p))
#
# <ipython-input-11-db383f91432d> in parseFeatures(pref_features)
#       5
#       6 def parseFeatures(pref_features):
# ----> 7     pd_df= pref_features.toPandas()
#       8     sallist=(pd_df[pd_df['prefkey'] == "desired_salary"]['prefvalue']).tolist()
#       9     recent_incomelist=(pd_df[pd_df['prefkey'] == "recent_pay"]['prefvalue']).tolist()
#
# /opt/anaconda3/envs/virtual_workspace/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# ...

# %%
#from pyspark.sql import SparkSession
import  json
import  pandas as pd
import  ast
#spark = SparkSession.builder.appName('profile pref map').getOrCreate()
'''merge_query="SELECT * from  ( SELECT t1.*,b1.* from  (SELECT a1.profileid as pro_pid, a1.email as pro_email,  a1.realname as pro_realname, a1.status as pro_status, a1.address as pro_address, a1.cityname as pro_cityname, a1.statename as pro_statename, a1.countrycode as pro_countycode, a1.postalcode as pro_postalcode, a1.exportdate as pro_exportdate, a2.profileid as pref_profileid, a2.prefkey as pref_prefkey, a2.prefvalue as pref_prefvalue, a2.modified as pref_modified,  a2.edited as pref_edited, a2.exportdate as pref_exportdate   from edgetest.pp_rsachdeva_profile a1  join  edgetest.pp_rsachdeva_preference a2  on a1.profileid=a2.profileid  WHERE a1.exportdate IS NOT NULL and a2.exportdate IS NOT NULL) t1  left join edgetest.pp_rsachdeva_resume b1  on b1.resumedid= regexp_replace(t1.pref_prefvalue, '\"', '')  and t1.pref_prefkey='default_resume' where b1.exportdate IS NOT NULL) t2"
edu_query="select profileid,prefkey,  get_json_object(prefvalue,'$.major') as major, get_json_object(prefvalue,'$.degree') as degree, get_json_object(prefvalue,'$.school') as school, get_json_object(prefvalue,'$.degree_code') as degreecode, get_json_object(prefvalue,'$.graduation_date') as graduationdate  from  edgetest.pp_rsachdeva_preference  WHERE exportdate IS NOT NULL  and prefkey like '%education%' "
exp_query='select profileid,prefkey, get_json_object(prefvalue,"$.end_date") as enddate, get_json_object(prefvalue,"$.start_date") as startdate, get_json_object(prefvalue,"$.company_name") as companyname, get_json_object(prefvalue,"$.is_current") as is_current, get_json_object(prefvalue,"$.job_title") as job_title, regexp_replace(regexp_replace(get_json_object(prefvalue,"$.job_desc"),"\n",""),"\r","") as job_desc, exportdate from  edgetest.pp_progpro_preference  WHERE  prefkey like "%work_history%"'
pref_other_features='select *  from edgetest.pp_rsachdeva_preference  WHERE prefkey not like "%work_history%" and prefkey not like "%education%" '
def execute_query(query):
    titlesDes_df=spark.sql(query)
    return titlesDes_df'''
def parseFeatures(pref_features):
    #pd_df=pref_features.toPandas()
    #pd_df=pref_features
    allprofiles=pref_features['profileid'].tolist()
    allfeatues=[]
    #{"income_pay": "", "income_type": "", "income_currency": ""}]
    for indx,eachprofile in enumerate(allprofiles):
        pro_featues = {}
        pd_df=pref_features[pref_features['profileid']==eachprofile]
        sallist = (pd_df[pd_df['prefkey'] == "desired_salary"]['prefvalue']).tolist()
        recent_incomelist = (pd_df[pd_df['prefkey'] == "recent_pay"]['prefvalue']).tolist()
        emp_type = (pd_df[pd_df['prefkey'] == "employment_type"]['prefvalue']).tolist()
        resumeid = (pd_df[pd_df['prefkey'] == "default_resume"]['prefvalue']).tolist()
        relocate_type = (pd_df[pd_df['prefkey'] == "relocate"]['prefvalue']).tolist()
        commute_type = (pd_df[pd_df['prefkey'] == "commute"]['prefvalue']).tolist()
        mgmt_exp_type = (pd_df[pd_df['prefkey'] == "mgmt_exp"]['prefvalue']).tolist()
        security_type = (pd_df[pd_df['prefkey'] == "security"]['prefvalue']).tolist()
        new_type = (pd_df[pd_df['prefkey'] == "abc"]['prefvalue']).tolist()
        pro_featues['profileid']=eachprofile
        try:
            pro_featues['TARG_PAY']=ast.literal_eval(sallist[0])[0]['income_pay']
            pro_featues['TARG_PAY_CRCY_TYP']=ast.literal_eval(sallist[0])[0]['income_currency']
            pro_featues['TARG_PAY_TYP']=ast.literal_eval(sallist[0])[0]['income_type']
        except :
            pro_featues['TARG_PAY']=""
            pro_featues['TARG_PAY_CRCY_TYP'] =""
            pro_featues['TARG_PAY_TYP']=""
        try:
            pro_featues['RCNT_PAY_CRCY_TYP'] = ast.literal_eval(recent_incomelist[0])['income_currency']
            pro_featues['RCNT_INCM_TYP'] = ast.literal_eval(recent_incomelist[0])['income_type']
            pro_featues['RCNT_INCM'] = ast.literal_eval(recent_incomelist[0])['income_pay']
        except:
            pro_featues['RCNT_PAY_CRCY_TYP'] = ""
            pro_featues['RCNT_INCM_TYP'] = ""
            pro_featues['RCNT_INCM']=""
        try:
            pro_featues['DES_JOB_TYP']=ast.literal_eval(emp_type[0])
        except:
            pro_featues['DES_JOB_TYP'] =emp_type
        try:
            pro_featues['resumeid'] = resumeid[0]
        except:
            pro_featues['resumeid'] = ""
        # try:
        #     pro_featues['relocate'] = relocate_type[indx]
        # except:
        #     pro_featues['relocate'] = ""
        # try:
        #     pro_featues['commute'] = ast.literal_eval(commute_type[indx])['maxcommute']
        # except:
        #     pro_featues['commute'] = ""
        # try:
        #     pro_featues['mgmt_exp'] = ast.literal_eval(mgmt_exp_type[indx])['mgmt']
        # except:
        #     pro_featues['mgmt_exp'] = ""
        # try:
        #     pro_featues['security'] = ast.literal_eval(security_type[indx])['security_clearance']
        # except:
        #     pro_featues['security'] = ""
        allfeatues.append(pro_featues)
    return allfeatues
if __name__ == '__main__':
    filename="/Users/smani/Desktop/query-hive-505970.csv"
    x=pd.read_csv(filename)
    p=parseFeatures(x)
    print(p)
    print(type(p))
    sdf = pd.DataFrame(p)
    print(type(sdf))
    trans_pdf=sdf.melt(['profileid',"resumeid"],var_name='questionid',value_name='response')
    trans_pdf.to_csv("pqr1.csv")
    # try:
    #     allprofilesData = execute_query(merge_query)
    #     allprofilesData.write.format("hive").mode("append").saveAsTable("edgetest.pp_rsachdeva_user")
    #     edu_spark_df = execute_query(edu_query)
    #     edu_spark_df.write.format("hive").mode("append").saveAsTable("edgetest.pp_rsachdeva_edu")
    #     exp_spark_df = execute_query(exp_query)
    #     exp_spark_df.write.format("hive").mode("append").saveAsTable("edgetest.pp_rsachdeva_exp")
    #     pref_features = execute_query(pref_other_features)
    #     data=parseFeatures(pref_features)
    #     pdf = pd.DataFrame(data)
    #     trans_pdf=sdf.melt(['profileid'],var_name='questionid',value_name='response')
    #     sdf = spark.createDataFrame(trans_pdf)
    #     sdf.write.format("hive").mode("append").saveAsTable("edgetest.pp_rsachdeva_features")
    #
    #
    #
    # except Exception as r2:
    #     raise(r2)
# Out:
# [{'profileid': 9496709, 'TARG_PAY': '', 'TARG_PAY_CRCY_TYP': '', 'TARG_PAY_TYP': '', 'RCNT_PAY_CRCY_TYP': '', 'RCNT_INCM_TYP': '', 'RCNT_INCM': '', 'DES_JOB_TYP': [], 'resumeid': ''}, {'profileid': 10388975, 'TARG_PAY': '', 'TARG_PAY_CRCY_TYP': '', 'TARG_PAY_TYP': '', 'RCNT_PAY_CRCY_TYP': '', 'RCNT_INCM_TYP': '', 'RCNT_INCM': '', 'DES_JOB_TYP': [], 'resumeid': ''}, {'profileid': 5268248, 'TARG_PAY': '', 'TARG_PAY_CRCY_TYP': '', 'TARG_PAY_TYP': '', 'RCNT_PAY_CRCY_TYP': '', 'RCNT_INCM_TYP': '', 'RCNT_INCM': '', 'DES_JOB_TYP': ['ETFE'], 'resumeid': ''}, {'profileid': 65729284, 'TARG_PAY': '', 'TARG_PAY_CRCY_TYP': '', 'TARG_PAY_TYP': '', 'RCNT_PAY_CRCY_TYP': '', 'RCNT_INCM_TYP': '', 'RCNT_INCM': '', 'DES_JOB_TYP': ['ETFT'], 'resumeid': '"RCL1LS5VL4R8Q64GNBF"'}, {'profileid': 65729284, 'TARG_PAY': '', 'TARG_PAY_CRCY_TYP': '', 'TARG_PAY_TYP': '', 'RCNT_PAY_CRCY_TYP': '', 'RCNT_INCM_TYP': '', 'RCNT_INCM': '', 'DES_JOB_TYP': ['ETFT'], 'resumeid': '"RCL1LS5VL4R8Q64GNBF"'}, {'profileid': 65729
# ...
