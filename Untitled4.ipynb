# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
df = pd.read_excel(r'/Users/smani/Downloads/skills_taxonomy.xlsx')
skills = df["skill"].tolist()
skill_l = []
for x in skills:
    if isinstance(x,str):
        for y in x :
            if y.isalpha():
                skill_l.append(x.lower())
                break
    else:
        pass
final_skill = list(dict.fromkeys(skill_l))
final_skill = final_skill[:12]
base_url  = 'https://en.wikipedia.org/wiki/'
final_data = []
for s in final_skill:
    
    skill_list=[]
    url1 = '{}{}'.format(base_url, s)
    url2 = '{}{}{}'.format(base_url,s,"_(disambiguation)")
    resp1 = requests.get(url1)
    resp2 = requests.get(url2)
    soup1 = BeautifulSoup(resp1.text, 'lxml')
    soup2 = BeautifulSoup(resp2.text, 'lxml')
    if resp1.status_code == 200:
        for item1 in soup1.select("#firstHeading"):
            skill_dict = {"Skill":s, "URL":url1, "PageHeading":item1.text}
            
            
    else :
            skill_dict={"Skill":s, "URL":"Web page does not exist", "PageHeading": "NA"}
            
    if resp2.status_code == 200:
        for item2 in soup2.select(".mw-headline"):
            skill_list.append(item2.text)
        #print(skill_list)
        skill_dict["Other_use"]= skill_list
        
    else :
        skill_dict["Other_use"]= "NA"
    print(skill_dict)

# %%
a_list.append(skill_dict)

# %%
a_list

# %%
import json
import wikipedia
import pandas as pd
import requests
from bs4 import BeautifulSoup
df = pd.read_excel(r'/Users/smani/Downloads/skills_taxonomy.xlsx')
skills = df["skill"].tolist()
skill_l = []
for x in skills:
    if isinstance(x,str):
        for y in x :
            if y.isalpha():
                skill_l.append(x.lower())
                break
    else:
        pass
final_skill = list(dict.fromkeys(skill_l))
final_skill = final_skill[:50]
base_url  = 'https://en.wikipedia.org/wiki/'
new_li1 = []
for s in final_skill:
    url1 = '{}{}'.format(base_url, s)
    url2 = '{}{}{}'.format(base_url,s,"_(disambiguation)")
    resp1 = requests.get(url1)
    resp2 = requests.get(url2)
    soup1 = BeautifulSoup(resp1.text, 'lxml')
    soup2 = BeautifulSoup(resp2.text, 'lxml')
    if resp1.status_code == 200:
        for item1 in soup1.select("#firstHeading"):
            new_li1.append({"Skill":s, "URL":url1, "PageHeading":item1.text})
            print(f"Skill: " + s + " URL:"  + url1 + " Page Heading: " + item1.text )
            
    else :
            new_li1.append({"Skill":s, "URL":"Web site does not exist", "PageHeading":"NA"})
            print(f"Skill: " + s + " URL: " + " Web site does not exist" + " Page Heading: NA " )
            
    if resp2.status_code ==200:
        for item2 in soup2.select(".mw-headline"):
            fr_esult = item2.getText()
            new_li1.exte({"Other Uses ":  fr_esult})
            print("Other Uses: " + fr_esult )
    else :
        new_li1.extend({"Other Uses ":  "NA"})
        print("Other Uses" + "NA")

# %%
new_li1

# %%
import requests
from bs4 import BeautifulSoup
base_url  = 'https://en.wikipedia.org/wiki/driver'

url4 = '{}{}'.format(base_url,"_(disambiguation)")
resp4 = requests.get(url4)
soup4 = BeautifulSoup(resp4.text, 'html.parser')
tempu = []
for item4 in soup4.select(".mw-headline"):
    result = item4.getText()
    print(*result, sep ", ")

# %%
f_result

# %%
import json
import wikipedia
import pandas as pd
import requests
from bs4 import BeautifulSoup
df = pd.read_excel(r'/Users/smani/Downloads/skills_taxonomy.xlsx')
skills = df["skill"].tolist()
skill_l = []
for x in skills:
    if isinstance(x,str):
        for y in x :
            if y.isalpha():
                skill_l.append(x.lower())
                break
    else:
        pass
final_skill = list(dict.fromkeys(skill_l))
final_skill = final_skill[:100]
base_url  = 'https://en.wikipedia.org/wiki/'
new1 = []
for s in final_skill:
    
    url3 = '{}{}{}'.format(base_url,s,"_(disambiguation)")
   
    resp3 = requests.get(url3)
 
    soup3 = BeautifulSoup(resp3.text, 'html.parser')
    
    if resp3.status_code ==200:
        for item3 in soup3.select(".mw-headline"):
            f_result = item3.getText()
            print (f_result)
            
            
            
    else :
       
        print("Other Uses" + "NA")

# %%
import json
import wikipedia
import pandas as pd
import requests
from bs4 import BeautifulSoup
df = pd.read_excel(r'/Users/smani/Downloads/skills_taxonomy.xlsx')
skills = df["skill"].tolist()
skill_l = []
for x in skills:
    if isinstance(x,str):
        for y in x :
            if y.isalpha():
                skill_l.append(x.lower())
                break
    else:
        pass
final_skill = list(dict.fromkeys(skill_l))
final_skill = final_skill[:20]
base_url  = 'https://en.wikipedia.org/wiki/'
new_li1 = []
for s in final_skill:
    new_list=[]
    url1 = '{}{}'.format(base_url, s)
    url2 = '{}{}{}'.format(base_url,s,"_(disambiguation)")
    resp1 = requests.get(url1)
    resp2 = requests.get(url2)
    soup1 = BeautifulSoup(resp1.text, 'lxml')
    soup2 = BeautifulSoup(resp2.text, 'lxml')
    if resp1.status_code == 200:
        for item1 in soup1.select("#firstHeading"):
            temp_dict={"Skill":s, "URL":url1, "PageHeading":item1.text}
            #print(f"Skill: " + s + " URL:"  + url1 + " Page Heading: " + item1.text )
    else :
        temp_dict={"Skill":s, "URL":"Web site does not exist", "PageHeading":"NA"}
        #print(f"Skill: " + s + " URL: " + " Web site does not exist" + " Page Heading: NA " )
    #new_li1.append(temp_dict)
    if resp2.status_code ==200:
        
        for item2 in soup2.select(".mw-headline"):
            
            new_list.append(item2.text)
            
            temp_dict = {"Other Uses:":new_list}
            
        #print(temp_dict)
        
    else :
        temp_dict["Other Uses "] = " NA"
        #print("Other Uses" + "NA")
new_li1.append(temp_dict)
print(new_li1)

# %%
new_li1

# %%
import requests
from bs4 import BeautifulSoup
base_url  = 'https://en.wikipedia.org/wiki/driver'

url4 = '{}{}'.format(base_url,"_(disambiguation)")
resp4 = requests.get(url4)
soup4 = BeautifulSoup(resp4.text, 'html.parser')
tempu = []
for item4 in soup4.select(".mw-headline"):
    tempu.append(item4.text)
print (tempu)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
df = pd.read_excel(r'/Users/smani/Downloads/skills_taxonomy.xlsx')
skills = df["skill"].tolist()
skill_l = []
for x in skills:
    if isinstance(x,str):
        for y in x :
            if y.isalpha():
                skill_l.append(x.lower())
                break
    else:
        pass
final_skill = list(dict.fromkeys(skill_l))

base_url  = 'https://en.wikipedia.org/wiki/'
final_data = []
for s in final_skill:
    skill_list=[]
    url1 = '{}{}'.format(base_url, s)
    url2 = '{}{}{}'.format(base_url,s,"_(disambiguation)")
    resp1 = requests.get(url1)
    resp2 = requests.get(url2)
    soup1 = BeautifulSoup(resp1.text, 'lxml')
    soup2 = BeautifulSoup(resp2.text, 'lxml')
    if resp1.status_code == 200:
        for item1 in soup1.select("#firstHeading"):
            skill_dict = {'Skill':s, 'URL':url1, 'PageHeading':item1.text}
    else :
            skill_dict={'Skill':s, 'URL':"Web page does not exist", 'PageHeading': "NA"}
    if resp2.status_code == 200:
        for item2 in soup2.select(".mw-headline"):
            skill_list.append(item2.text)
        #print(skill_list)
        skill_dict['Other_use']= skill_list
    else :
        skill_dict['Other_use']= "NA"
    print(skill_dict)
    final_data.append(skill_dict)
#f=open("abc.json","w")
#f.write(str(final_data))
#f.close()
# Out:
# {'Skill': 'zenz', 'URL': 'https://en.wikipedia.org/wiki/zenz', 'PageHeading': 'Zenz', 'Other_use': ['See also']}
# {'Skill': 'xextx', 'URL': 'Web page does not exist', 'PageHeading': 'NA', 'Other_use': 'NA'}
# {'Skill': 'xintx', 'URL': 'Web page does not exist', 'PageHeading': 'NA', 'Other_use': 'NA'}
# {'Skill': 'rrnarr', 'URL': 'Web page does not exist', 'PageHeading': 'NA', 'Other_use': 'NA'}
# {'Skill': 'udayu', 'URL': 'Web page does not exist', 'PageHeading': 'NA', 'Other_use': 'NA'}
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ...

# %%
import json
with open ("skillmap_new2.json","w")as f:
    json.dump(final_data,f)

# %%
import pandas as pd

df = pd.read_json(r'/Users/smani/Downloads/Scraped_IT_Skills.json')

# %%
df
# Out:
#           Skill(SN)                               Skill(FN)  \
# 0                 A                         Ampere\n Anchor
# 1             A/N/K          alphabetic, numeric,  katakana
# 2              a11y                           accessibility
# 3               A2A              application-to-application
# 4                AA                           anti-aliasing
# ...             ...                                     ...
# 4104            ZTE  Zhong Xing Telecommunication Equipment
# 4105           ZTLP           Zero Transmission Level Point
# 4106            zsh                                 Z shell
# 4107  ZV port / ZVP                       Zoomed Video port
# 4108          Â\xa0                                 zapping
#
#                                             Description
# 0      Current measurement unit\n HTML tag, a link t...
# 1     Pertaining to alphabetic, numeric,  or katakan...
# 2     There are eleven letters between the    "a" an...
# ...

# %%
import requests
import time
import json
import bs4
from bs4 import BeautifulSoup
import pandas as pd


#url_n = 'https://www.consp.com/it-terminology-dictionary-'+str(items)
    #print(url_n)
url = 'https://www.consp.com/it-terminology-dictionary-a'
r = requests.get(url,timeout=10)
html = r.text
soup = bs4.BeautifulSoup(html, 'lxml')
items = soup.select(".ss-text")
result = items[0]
row = [i.text.replace('\n','') for i in result.select('td')]
row_data = [col.text.strip('\n') for col in result.select('td')]
#l = row_data   
#n = 3 
#xlist = [l[i:i + n] for i in range(0, len(l), n)]  
#l1 = ["Skill(SN)","Skill(FN)","Description"]
#for i in xlist:
    #final_r = dict(zip(l1,i))
    #print(final_r)
    #f1.write(str(final_r) + ",")

# %%
row
# Out:
# ['A',
#  ' Ampere Anchor',
#  ' Current measurement unit HTML tag, a link to another        location',
#  'A/N/K',
#  'alphabetic, numeric,  katakana',
#  'Pertaining to alphabetic, numeric,  or katakana characters.',
#  'a11y',
#  'accessibility',
#  'There are eleven letters between the    "a" and the "y". ',
#  'A2A',
#  'application-to-application',
#  'An approach to enterprise application integration that provides  visibility into internal systems, so that these systems can share  information or business processes.',
#  'AA',
#  'anti-aliasing',
#  'the technique of minimizing the distortion artifacts known as aliasing when representing a high-resolution signal at a lower resolution',
#  'AA',
#  'automated attendant',
#  'A device, typically attached to a private branch exchange or voice mail system, that answers incoming calls.',
#  'AAA',
#  'authentication, authorization, and accounting',
# ...

# %%
row = [i.text.replace('\n','<br />') for i in result.select('td')]

# %%
row
# Out:
# ['A',
#  ' Ampere<br /> Anchor',
#  ' Current measurement unit<br /> HTML tag, a link to another<br />        location',
#  'A/N/K',
#  'alphabetic, numeric,  katakana',
#  'Pertaining to alphabetic, numeric,  or katakana characters.',
#  'a11y',
#  'accessibility',
#  'There are eleven letters between the    "a" and the "y". ',
#  'A2A',
#  'application-to-application',
#  'An approach to enterprise application integration that provides  visibility into internal systems, so that these systems can share  information or business processes.',
#  'AA',
#  'anti-aliasing',
#  'the technique of minimizing the distortion artifacts known as aliasing when representing a high-resolution signal at a lower resolution',
#  'AA',
#  'automated attendant',
#  'A device, typically attached to a private branch exchange or voice mail system, that answers incoming calls.',
#  'AAA',
#  'authentication, authorization, and accounting',
# ...
